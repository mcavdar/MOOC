# %%
# %%bash
# tr 'A-Z' 'a-z' < nyt_200811.txt | tr -sc 'A-Za-z' '\n' | sort | uniq -c
# Out:
#   26747 a
#       3 aa
#       3 aaa
#       1 aalborg
#       1 aaliyah
#       1 aalto
#       2 aardvark
#       3 aardvarks
#      25 aaron
#       1 aarp
#       1 abandoibarra
#      18 abandon
#      22 abandoned
#       4 abandoning
#       1 abandonment
#       2 abandonments
#       1 abati
#       2 abba
#       8 abbas
#      12 abbassi
#       2 abbe
#       4 abbey
#       1 abbott
#       3 abbreviated
#       2 abby
#      77 abc
#       1 abchome
#       1 abcnews
#       4 abdel
#       1 abdellatif
#       3 abderrahim
#       3 abdi
#       1 abdicating
#      10 abdirahman
#       2 abdominal
#       4 abdoulaye
#       1 abdu
#       4 abducted
#       4 abduction
#       1 abductor
#      14 abdul
#      19 abdullah
#       6 abe
#       1 abel
#       5 abelson
#       1 abenjamin
#       6 abercrombie
#      15 abernathy
#       2 aberration
#       1 abetted
#       1 abetting
#       1 abhorrent
#       3 abide
#       1 abided
#       3 abiding
# ...
